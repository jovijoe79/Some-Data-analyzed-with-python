# %% [markdown]
# # Human Predictive AI

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\DELL\Documents\Train.csv")
df
# Out:
#       Gender  Height (cm)  Weight (kg) Blood Pressure (s/d)  \
# 0       Male       171.15        86.19              151/109
# 1       Male       172.95        79.64              134/112
# 2     Female       155.95        49.17              160/101
# 3     Female       169.08        56.02               133/94
# 4     Female       163.76        73.97              170/106
# ...      ...          ...          ...                  ...
# 2995    Male       161.63        88.32               134/91
# 2996    Male       163.44        93.22               110/78
# 2997    Male       177.86        86.26              159/116
# 2998  Female       162.29        41.37               134/82
# 2999    Male       175.34        78.72               167/91
#
#       Cholesterol Level (mg/dL)   BMI  Blood Glucose Level (mg/dL)  \
# 0                        259.47 29.42                       157.65
# 1                        263.63 26.63                       118.51
# ...

# %%
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %%
df.dropna()
# Out:
#       Gender  Height (cm)  Weight (kg) Blood Pressure (s/d)  \
# 8     Female       164.55        74.41              152/119
# 12      Male       173.34       102.46              145/108
# 13    Female       159.08        67.08               151/79
# 14      Male       180.78        89.76              143/101
# 16    Female       165.89        70.36              154/109
# ...      ...          ...          ...                  ...
# 2960  Female       159.99        66.47              161/106
# 2966    Male       170.80        83.05               162/89
# 2968  Female       166.15        43.08              144/103
# 2981  Female       160.00        69.71               125/99
# 2996    Male       163.44        93.22               110/78
#
#       Cholesterol Level (mg/dL)   BMI  Blood Glucose Level (mg/dL)  \
# 8                        204.24 27.48                       137.02
# 12                       289.22 34.10                       124.85
# ...

# %%
df
# Out:
#       Gender  Height (cm)  Weight (kg) Blood Pressure (s/d)  \
# 0       Male       171.15        86.19              151/109
# 1       Male       172.95        79.64              134/112
# 2     Female       155.95        49.17              160/101
# 3     Female       169.08        56.02               133/94
# 4     Female       163.76        73.97              170/106
# ...      ...          ...          ...                  ...
# 2995    Male       161.63        88.32               134/91
# 2996    Male       163.44        93.22               110/78
# 2997    Male       177.86        86.26              159/116
# 2998  Female       162.29        41.37               134/82
# 2999    Male       175.34        78.72               167/91
#
#       Cholesterol Level (mg/dL)   BMI  Blood Glucose Level (mg/dL)  \
# 0                        259.47 29.42                       157.65
# 1                        263.63 26.63                       118.51
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 26 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Gender                       3000 non-null   object
#  1   Height (cm)                  3000 non-null   float64
#  2   Weight (kg)                  3000 non-null   float64
#  3   Blood Pressure (s/d)         3000 non-null   object
#  4   Cholesterol Level (mg/dL)    3000 non-null   float64
#  5   BMI                          3000 non-null   float64
#  6   Blood Glucose Level (mg/dL)  3000 non-null   float64
#  7   Bone Density (g/cm²)         3000 non-null   float64
#  8   Vision Sharpness             3000 non-null   float64
#  9   Hearing Ability (dB)         3000 non-null   float64
#  10  Physical Activity Level      3000 non-null   object
#  11  Smoking Status               3000 non-null   object
# ...

# %%
df = df.dropna()

# %%
df
# Out:
#       Gender  Height (cm)  Weight (kg) Blood Pressure (s/d)  \
# 8     Female       164.55        74.41              152/119
# 12      Male       173.34       102.46              145/108
# 13    Female       159.08        67.08               151/79
# 14      Male       180.78        89.76              143/101
# 16    Female       165.89        70.36              154/109
# ...      ...          ...          ...                  ...
# 2960  Female       159.99        66.47              161/106
# 2966    Male       170.80        83.05               162/89
# 2968  Female       166.15        43.08              144/103
# 2981  Female       160.00        69.71               125/99
# 2996    Male       163.44        93.22               110/78
#
#       Cholesterol Level (mg/dL)   BMI  Blood Glucose Level (mg/dL)  \
# 8                        204.24 27.48                       137.02
# 12                       289.22 34.10                       124.85
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 576 entries, 8 to 2996
# Data columns (total 26 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Gender                       576 non-null    object
#  1   Height (cm)                  576 non-null    float64
#  2   Weight (kg)                  576 non-null    float64
#  3   Blood Pressure (s/d)         576 non-null    object
#  4   Cholesterol Level (mg/dL)    576 non-null    float64
#  5   BMI                          576 non-null    float64
#  6   Blood Glucose Level (mg/dL)  576 non-null    float64
#  7   Bone Density (g/cm²)         576 non-null    float64
#  8   Vision Sharpness             576 non-null    float64
#  9   Hearing Ability (dB)         576 non-null    float64
#  10  Physical Activity Level      576 non-null    object
#  11  Smoking Status               576 non-null    object
#  12  Alcohol Consumption          576 non-null    object
# ...

# %%
df.reset_index(drop=True)
# Out:
#      Gender  Height (cm)  Weight (kg) Blood Pressure (s/d)  \
# 0    Female       164.55        74.41              152/119
# 1      Male       173.34       102.46              145/108
# 2    Female       159.08        67.08               151/79
# 3      Male       180.78        89.76              143/101
# 4    Female       165.89        70.36              154/109
# ..      ...          ...          ...                  ...
# 571  Female       159.99        66.47              161/106
# 572    Male       170.80        83.05               162/89
# 573  Female       166.15        43.08              144/103
# 574  Female       160.00        69.71               125/99
# 575    Male       163.44        93.22               110/78
#
#      Cholesterol Level (mg/dL)   BMI  Blood Glucose Level (mg/dL)  \
# 0                       204.24 27.48                       137.02
# 1                       289.22 34.10                       124.85
# ...

# %%
pd.set_option('display.max.columns', 28)

# %%
df
# Out:
#       Gender  Height (cm)  Weight (kg) Blood Pressure (s/d)  \
# 8     Female       164.55        74.41              152/119
# 12      Male       173.34       102.46              145/108
# 13    Female       159.08        67.08               151/79
# 14      Male       180.78        89.76              143/101
# 16    Female       165.89        70.36              154/109
# ...      ...          ...          ...                  ...
# 2960  Female       159.99        66.47              161/106
# 2966    Male       170.80        83.05               162/89
# 2968  Female       166.15        43.08              144/103
# 2981  Female       160.00        69.71               125/99
# 2996    Male       163.44        93.22               110/78
#
#       Cholesterol Level (mg/dL)   BMI  Blood Glucose Level (mg/dL)  \
# 8                        204.24 27.48                       137.02
# 12                       289.22 34.10                       124.85
# ...

# %%
df['Diet'].unique()
# Out:
# array(['Low-carb', 'Vegetarian', 'High-fat', 'Balanced'], dtype=object)

# %%
df['Diet'] = df['Diet'].str.replace('Low-carb','Low-carb')
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_3024\3058364709.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Diet'] = df['Diet'].str.replace('Low-carb','Low-carb')

# %%
df['Diet'] = df['Diet'].replace('Low-carbonon', 'Low-carbon')
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_3024\3010930373.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Diet'] = df['Diet'].replace('Low-carbonon', 'Low-carbon')

# %%
df
# Out:
#       Gender  Height (cm)  Weight (kg) Blood Pressure (s/d)  \
# 8     Female       164.55        74.41              152/119
# 12      Male       173.34       102.46              145/108
# 13    Female       159.08        67.08               151/79
# 14      Male       180.78        89.76              143/101
# 16    Female       165.89        70.36              154/109
# ...      ...          ...          ...                  ...
# 2960  Female       159.99        66.47              161/106
# 2966    Male       170.80        83.05               162/89
# 2968  Female       166.15        43.08              144/103
# 2981  Female       160.00        69.71               125/99
# 2996    Male       163.44        93.22               110/78
#
#       Cholesterol Level (mg/dL)   BMI  Blood Glucose Level (mg/dL)  \
# 8                        204.24 27.48                       137.02
# 12                       289.22 34.10                       124.85
# ...

# %%
male = df[df['Gender'].str.contains('Male')]

# %%
female = df[df['Gender'].str.contains('Female')]

# %%
count_male = male.value_counts()

# %%
count_female = female.value_counts()

# %%
df
# Out:
#       Gender  Height (cm)  Weight (kg) Blood Pressure (s/d)  \
# 8     Female       164.55        74.41              152/119
# 12      Male       173.34       102.46              145/108
# 13    Female       159.08        67.08               151/79
# 14      Male       180.78        89.76              143/101
# 16    Female       165.89        70.36              154/109
# ...      ...          ...          ...                  ...
# 2960  Female       159.99        66.47              161/106
# 2966    Male       170.80        83.05               162/89
# 2968  Female       166.15        43.08              144/103
# 2981  Female       160.00        69.71               125/99
# 2996    Male       163.44        93.22               110/78
#
#       Cholesterol Level (mg/dL)   BMI  Blood Glucose Level (mg/dL)  \
# 8                        204.24 27.48                       137.02
# 12                       289.22 34.10                       124.85
# ...

# %%
count_dis = df['Chronic Diseases'].value_counts()

# %%
count_dis.plot(kind='pie', ylabel = '', title='Common Diseases', figsize = (10, 8))
# Out:
# <Axes: title={'center': 'Common Diseases'}>

# %%
count_smoke = df['Smoking Status'].value_counts()

# %%
count_smoke.plot(kind='barh', color='black', title='Smoking Status', ylabel = '')
# Out:
# <Axes: title={'center': 'Smoking Status'}>

# %%
top = df['Hearing Ability (dB)'].head(10)

# %%
top.plot(kind='bar')
# Out:
# <Axes: >

# %%
top_age = df['Age (years)'].head(20)

# %%
top_age.plot(kind='barh', title='Top 20 Aged people', color='red')
# Out:
# <Axes: title={'center': 'Top 20 Aged people'}>
