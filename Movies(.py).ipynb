# %% [markdown]
# # Second Pandas Project

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\DELL\Documents\titles.csv")
df
# Out:
#              id                                      title   type  \
# 0      ts300399        Five Came Back: The Reference Films   SHOW
# 1       tm84618                                Taxi Driver  MOVIE
# 2      tm154986                                Deliverance  MOVIE
# 3      tm127384            Monty Python and the Holy Grail  MOVIE
# 4      tm120801                            The Dirty Dozen  MOVIE
# ...         ...                                        ...    ...
# 5845  tm1014599                                  Fine Wine  MOVIE
# 5846   tm898842                                C/O Kaadhal  MOVIE
# 5847  tm1059008                                    Lokillo  MOVIE
# 5848  tm1035612  Dad Stop Embarrassing Me - The Afterparty  MOVIE
# 5849   ts271048         Mighty Little Bheem: Kite Festival   SHOW
#
#                                             description  release_year  \
# 0     This collection includes 12 World War II-era p...          1945
# ...

# %%
df2 = pd.read_csv(r"C:\Users\DELL\Documents\credits.csv")
df2
# Out:
#        person_id         id                name                character  \
# 0           3748    tm84618      Robert De Niro            Travis Bickle
# 1          14658    tm84618        Jodie Foster            Iris Steensma
# 2           7064    tm84618       Albert Brooks                      Tom
# 3           3739    tm84618       Harvey Keitel  Matthew 'Sport' Higgins
# 4          48933    tm84618     Cybill Shepherd                    Betsy
# ...          ...        ...                 ...                      ...
# 77796     736339  tm1059008    Adelaida Buscato                María Paz
# 77797     399499  tm1059008  Luz Stella Luengas             Karen Bayona
# 77798     373198  tm1059008         Inés Prieto                    Fanny
# 77799     378132  tm1059008        Isabel Gaona                   Cacica
# 77800    1950416  tm1059008      Julian Gaviria                      NaN
#
#            role
# 0         ACTOR
# 1         ACTOR
# 2         ACTOR
# 3         ACTOR
# ...

# %%
df3 = df.merge(df2, how= 'inner', on= 'id')
df3
# Out:
#               id        title   type  \
# 0        tm84618  Taxi Driver  MOVIE
# 1        tm84618  Taxi Driver  MOVIE
# 2        tm84618  Taxi Driver  MOVIE
# 3        tm84618  Taxi Driver  MOVIE
# 4        tm84618  Taxi Driver  MOVIE
# ...          ...          ...    ...
# 77796  tm1059008      Lokillo  MOVIE
# 77797  tm1059008      Lokillo  MOVIE
# 77798  tm1059008      Lokillo  MOVIE
# 77799  tm1059008      Lokillo  MOVIE
# 77800  tm1059008      Lokillo  MOVIE
#
#                                              description  release_year  \
# 0      A mentally unstable Vietnam War veteran works ...          1976
# 1      A mentally unstable Vietnam War veteran works ...          1976
# 2      A mentally unstable Vietnam War veteran works ...          1976
# 3      A mentally unstable Vietnam War veteran works ...          1976
# 4      A mentally unstable Vietnam War veteran works ...          1976
# ...                                                  ...           ...
# ...

# %%
df3['seasons'].unique()
# Out:
# array([nan,  4.,  1.,  9., 24.,  5., 39., 10., 13., 42., 25., 21., 37.,
#         8., 29.,  7., 11., 14.,  6., 32., 15., 12., 19.,  2., 20.,  3.,
#        16.])

# %%
df3.drop_duplicates()
# Out:
#               id        title   type  \
# 0        tm84618  Taxi Driver  MOVIE
# 1        tm84618  Taxi Driver  MOVIE
# 2        tm84618  Taxi Driver  MOVIE
# 3        tm84618  Taxi Driver  MOVIE
# 4        tm84618  Taxi Driver  MOVIE
# ...          ...          ...    ...
# 77796  tm1059008      Lokillo  MOVIE
# 77797  tm1059008      Lokillo  MOVIE
# 77798  tm1059008      Lokillo  MOVIE
# 77799  tm1059008      Lokillo  MOVIE
# 77800  tm1059008      Lokillo  MOVIE
#
#                                              description  release_year  \
# 0      A mentally unstable Vietnam War veteran works ...          1976
# 1      A mentally unstable Vietnam War veteran works ...          1976
# 2      A mentally unstable Vietnam War veteran works ...          1976
# 3      A mentally unstable Vietnam War veteran works ...          1976
# 4      A mentally unstable Vietnam War veteran works ...          1976
# ...                                                  ...           ...
# ...

# %%
df3 = df3.fillna('')
df3
# Out:
#               id        title   type  \
# 0        tm84618  Taxi Driver  MOVIE
# 1        tm84618  Taxi Driver  MOVIE
# 2        tm84618  Taxi Driver  MOVIE
# 3        tm84618  Taxi Driver  MOVIE
# 4        tm84618  Taxi Driver  MOVIE
# ...          ...          ...    ...
# 77796  tm1059008      Lokillo  MOVIE
# 77797  tm1059008      Lokillo  MOVIE
# 77798  tm1059008      Lokillo  MOVIE
# 77799  tm1059008      Lokillo  MOVIE
# 77800  tm1059008      Lokillo  MOVIE
#
#                                              description  release_year  \
# 0      A mentally unstable Vietnam War veteran works ...          1976
# 1      A mentally unstable Vietnam War veteran works ...          1976
# 2      A mentally unstable Vietnam War veteran works ...          1976
# 3      A mentally unstable Vietnam War veteran works ...          1976
# 4      A mentally unstable Vietnam War veteran works ...          1976
# ...                                                  ...           ...
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77801 entries, 0 to 77800
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    77801 non-null  object
#  1   title                 77801 non-null  object
#  2   type                  77801 non-null  object
#  3   description           77801 non-null  object
#  4   release_year          77801 non-null  int64
#  5   age_certification     77801 non-null  object
#  6   runtime               77801 non-null  int64
#  7   genres                77801 non-null  object
#  8   production_countries  77801 non-null  object
#  9   seasons               77801 non-null  object
#  10  imdb_id               77801 non-null  object
#  11  imdb_score            77801 non-null  object
#  12  imdb_votes            77801 non-null  object
#  13  tmdb_popularity       77801 non-null  object
#  14  tmdb_score            77801 non-null  object
# ...

# %%
df3['type'].unique()
# set_index for visualization
# Out:
# array(['MOVIE', 'SHOW'], dtype=object)

# %%
df3['release_year'].unique()
# set_index for visualization
# Out:
# array([1976, 1972, 1975, 1967, 1969, 1979, 1971, 1980, 1961, 1966, 1954,
#        1958, 1977, 1963, 1956, 1960, 1973, 1974, 1959, 1978, 1989, 1990,
#        1987, 1984, 1983, 1982, 1986, 1981, 1988, 1985, 2000, 1996, 1997,
#        1995, 1994, 1999, 1998, 1993, 1992, 1991, 2008, 2002, 2010, 2005,
#        2007, 2004, 2006, 2009, 2003, 2001, 2011, 2012, 2013, 2014, 2015,
#        2016, 2018, 2017, 2019, 2020, 2022, 2021], dtype=int64)

# %%
df3['age_certification'].unique()
#set_index for visualization
# Out:
# array(['R', 'PG', '', 'TV-14', 'PG-13', 'TV-MA', 'TV-PG', 'TV-Y', 'TV-G',
#        'TV-Y7', 'G', 'NC-17'], dtype=object)

# %%
df3['genres'].unique()
# Out:
# array(["['drama', 'crime']",
#        "['drama', 'action', 'thriller', 'european']",
#        "['fantasy', 'action', 'comedy']", ...,
#        "['drama', 'animation', 'music']",
#        "['animation', 'family', 'scifi']",
#        "['documentation', 'music', 'reality']"], dtype=object)

# %%
df3['production_countries'].unique()
# get top 10 countries for visualization
# Out:
# array(["['US']", "['GB']", "['GB', 'US']", "['EG']", "['DE']", "['IN']",
#        "['SU', 'IN']", "['LB', 'CA', 'FR']", '[]', "['LB']",
#        "['DZ', 'EG']", "['CA', 'FR', 'LB']", "['US', 'GB']",
#        "['US', 'IT']", "['JP']", "['AR']", "['FR', 'EG']", "['FR', 'LB']",
#        "['CA', 'US']", "['US', 'FR']", "['JP', 'US']", "['US', 'CA']",
#        "['DE', 'US']", "['PE', 'US', 'BR']", "['IT', 'US', 'FR']",
#        "['IE', 'GB', 'DE', 'FR']", "['HK', 'US']", "['AU']", "['FR']",
#        "['DE', 'GH', 'GB', 'US', 'BF']", "['MX']", "['ES', 'AR']",
#        "['CO']", "['PS', 'US', 'FR', 'DE']", "['FR', 'NO', 'LB', 'BE']",
#        "['BE', 'FR', 'IT', 'LB']", "['TR']", "['IN', 'SU']", "['DK']",
#        "['CA']", "['DE', 'GB', 'US', 'BS', 'CZ']", "['MT', 'GB', 'US']",
#        "['AU', 'DE', 'GB', 'US']", "['US', 'JP']", "['BE', 'US']",
#        "['HK']", "['IT']", "['US', 'FR', 'DE', 'GB']",
#        "['GB', 'US', 'FR', 'DE']", "['IT', 'US']", "['US', 'ZA']",
# ...

# %%
df3['imdb_score'].unique()
# Out:
# array([8.2, 7.7, 8.8, 8.0, 5.8, 7.5, 7.3, 8.1, 6.2, 7.2, 2.1, 7.6, 7.4,
#        6.7, 6.1, 6.4, 5.1, 6.5, 6.6, 7.8, 4.6, 4.4, 8.9, 8.7, 8.3, 6.9,
#        7.1, 4.9, 7.9, 5.9, 7.0, 6.0, 5.6, '', 5.4, 6.3, 5.2, 3.8, 4.8,
#        8.4, 8.6, 8.5, 4.5, 6.8, 9.0, 5.5, 5.0, 9.5, 9.3, 5.7, 4.0, 3.9,
#        3.6, 4.1, 5.3, 4.7, 2.9, 3.4, 4.3, 2.0, 4.2, 3.2, 3.5, 1.7, 9.2,
#        3.0, 3.7, 1.9, 2.8, 1.5, 2.7, 9.1, 3.3, 2.3, 3.1, 2.2, 1.6, 2.5,
#        2.6], dtype=object)

# %%
df3['seasons'].unique()
# Out:
# array(['', 4.0, 1.0, 9.0, 24.0, 5.0, 39.0, 10.0, 13.0, 42.0, 25.0, 21.0,
#        37.0, 8.0, 29.0, 7.0, 11.0, 14.0, 6.0, 32.0, 15.0, 12.0, 19.0, 2.0,
#        20.0, 3.0, 16.0], dtype=object)

# %%
df3
# Out:
#               id        title   type  \
# 0        tm84618  Taxi Driver  MOVIE
# 1        tm84618  Taxi Driver  MOVIE
# 2        tm84618  Taxi Driver  MOVIE
# 3        tm84618  Taxi Driver  MOVIE
# 4        tm84618  Taxi Driver  MOVIE
# ...          ...          ...    ...
# 77796  tm1059008      Lokillo  MOVIE
# 77797  tm1059008      Lokillo  MOVIE
# 77798  tm1059008      Lokillo  MOVIE
# 77799  tm1059008      Lokillo  MOVIE
# 77800  tm1059008      Lokillo  MOVIE
#
#                                              description  release_year  \
# 0      A mentally unstable Vietnam War veteran works ...          1976
# 1      A mentally unstable Vietnam War veteran works ...          1976
# 2      A mentally unstable Vietnam War veteran works ...          1976
# 3      A mentally unstable Vietnam War veteran works ...          1976
# 4      A mentally unstable Vietnam War veteran works ...          1976
# ...                                                  ...           ...
# ...

# %%
df3 = df3.drop_duplicates(subset = 'title', keep= 'first')
# checks for duplicates in individual columns and removes it

# %%
df3 = df3.reset_index(drop=True)
df3
# Out:
#              id                            title   type  \
# 0       tm84618                      Taxi Driver  MOVIE
# 1      tm154986                      Deliverance  MOVIE
# 2      tm127384  Monty Python and the Holy Grail  MOVIE
# 3      tm120801                  The Dirty Dozen  MOVIE
# 4       ts22164     Monty Python's Flying Circus   SHOW
# ...         ...                              ...    ...
# 5436  tm1216735                  Sun of the Soil  MOVIE
# 5437   tm985215             Princess 'Daya'Reese  MOVIE
# 5438  tm1097142                         My Bride  MOVIE
# 5439  tm1014599                        Fine Wine  MOVIE
# 5440  tm1059008                          Lokillo  MOVIE
#
#                                             description  release_year  \
# 0     A mentally unstable Vietnam War veteran works ...          1976
# 1     Intent on seeing the Cahulawassee River before...          1972
# 2     King Arthur, accompanied by his squire, recrui...          1975
# ...

# %%
df3.set_index('age_certification')
# Out:
#                           id                            title   type  \
# age_certification
# R                    tm84618                      Taxi Driver  MOVIE
# R                   tm154986                      Deliverance  MOVIE
# PG                  tm127384  Monty Python and the Holy Grail  MOVIE
#                     tm120801                  The Dirty Dozen  MOVIE
# TV-14                ts22164     Monty Python's Flying Circus   SHOW
# ...                      ...                              ...    ...
#                    tm1216735                  Sun of the Soil  MOVIE
#                     tm985215             Princess 'Daya'Reese  MOVIE
#                    tm1097142                         My Bride  MOVIE
#                    tm1014599                        Fine Wine  MOVIE
#                    tm1059008                          Lokillo  MOVIE
#
#                                                          description  \
# age_certification
# ...

# %%
df3 = df3.sort_values(by='title', ascending=True)
df3
# Out:
#              id                         title   type  \
# 1606  tm1063792                                MOVIE
# 3046   tm820190                        #Alive  MOVIE
# 3845   tm817087  #AnneFrank. Parallel Stories  MOVIE
# 2710   tm371188             #FriendButMarried  MOVIE
# 4252   tm846354           #FriendButMarried 2  MOVIE
# ...         ...                           ...    ...
# 3910   tm931701                       Òlòtūré  MOVIE
# 4367   ts223454                 นางสาวก้นครัว   SHOW
# 3859   ts223062             ปริศนาล่าข้ามเวลา   SHOW
# 4204   ts222901                      糖糖Online   SHOW
# 5332   ts307816                        냉면 랩소디   SHOW
#
#                                             description  release_year  \
# 1606                                                             2015
# 3046  As a grisly virus rampages a city, a lone man ...          2020
# 3845  One single Anne Frank moves us more than the c...          2019
# ...

# %%
for x in df3.index:
    if df3.loc[x, 'title'] == '':
        df3.drop(x, inplace = True)

# %%
df3
# Out:
#             id                         title   type  \
# 3046  tm820190                        #Alive  MOVIE
# 3845  tm817087  #AnneFrank. Parallel Stories  MOVIE
# 2710  tm371188             #FriendButMarried  MOVIE
# 4252  tm846354           #FriendButMarried 2  MOVIE
# 1520  tm286268                     #Rucker50  MOVIE
# ...        ...                           ...    ...
# 3910  tm931701                       Òlòtūré  MOVIE
# 4367  ts223454                 นางสาวก้นครัว   SHOW
# 3859  ts223062             ปริศนาล่าข้ามเวลา   SHOW
# 4204  ts222901                      糖糖Online   SHOW
# 5332  ts307816                        냉면 랩소디   SHOW
#
#                                             description  release_year  \
# 3046  As a grisly virus rampages a city, a lone man ...          2020
# 3845  One single Anne Frank moves us more than the c...          2019
# 2710  Pining for his high school crush for years, a ...          2018
# ...

# %%
age_cert = df3['age_certification'].value_counts()
# a way to visualize str data

# %%
age_cert.plot(kind= 'pie', figsize = (10,10), ylabel= 'age_cert')
# Out:
# <Axes: ylabel='age_cert'>

# %%
df3
# Out:
#             id                         title   type  \
# 3046  tm820190                        #Alive  MOVIE
# 3845  tm817087  #AnneFrank. Parallel Stories  MOVIE
# 2710  tm371188             #FriendButMarried  MOVIE
# 4252  tm846354           #FriendButMarried 2  MOVIE
# 1520  tm286268                     #Rucker50  MOVIE
# ...        ...                           ...    ...
# 3910  tm931701                       Òlòtūré  MOVIE
# 4367  ts223454                 นางสาวก้นครัว   SHOW
# 3859  ts223062             ปริศนาล่าข้ามเวลา   SHOW
# 4204  ts222901                      糖糖Online   SHOW
# 5332  ts307816                        냉면 랩소디   SHOW
#
#                                             description  release_year  \
# 3046  As a grisly virus rampages a city, a lone man ...          2020
# 3845  One single Anne Frank moves us more than the c...          2019
# 2710  Pining for his high school crush for years, a ...          2018
# ...

# %%
runtime = df3.sort_values(by='runtime', ascending = False)

# %%
top20_runtime = runtime.head(20)
#top20_runtime

# %%
top20_runtime.plot(kind='barh', xlabel = 'top20_runtime', y = 'runtime', x = 'title', color = 'brown')
# Out:
# <Axes: xlabel='top20_runtime', ylabel='title'>

# %%
df3['imdb_score'].unique()
# Out:
# array([6.3, 6.5, 6.8, 6.9, 5.2, '', 5.1, 5.6, 7.7, 5.7, 7.5, 7.9, 7.0,
#        6.0, 6.2, 8.2, 6.7, 7.6, 5.8, 7.1, 6.6, 8.0, 8.4, 4.5, 7.3, 8.3,
#        3.3, 2.5, 7.4, 5.9, 4.3, 3.9, 6.1, 7.8, 5.4, 5.5, 5.3, 3.8, 5.0,
#        7.2, 6.4, 2.3, 8.7, 4.7, 4.6, 8.1, 4.4, 3.5, 1.5, 8.6, 2.9, 3.7,
#        4.9, 2.6, 4.2, 3.1, 3.2, 4.8, 4.0, 9.0, 9.3, 2.2, 4.1, 8.8, 8.5,
#        9.5, 8.9, 3.0, 3.4, 2.7, 3.6, 2.1, 2.0, 1.7, 9.1, 1.9, 2.8, 1.6,
#        9.2], dtype=object)

# %%
df3['imdb_score'] = pd.to_numeric(df['imdb_score'], errors='coerce')
# converting a string column to float or int

# %%
for x in df3['imdb_score']:
    if x > 7.0:
        high_rate = x

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5440 entries, 3046 to 5332
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    5440 non-null   object
#  1   title                 5440 non-null   object
#  2   type                  5440 non-null   object
#  3   description           5440 non-null   object
#  4   release_year          5440 non-null   int64
#  5   age_certification     5440 non-null   object
#  6   runtime               5440 non-null   int64
#  7   genres                5440 non-null   object
#  8   production_countries  5440 non-null   object
#  9   seasons               5440 non-null   object
#  10  imdb_id               5440 non-null   object
#  11  imdb_score            5440 non-null   object
#  12  imdb_votes            5440 non-null   object
#  13  tmdb_popularity       5440 non-null   object
#  14  tmdb_score            5440 non-null   object
# ...

# %%
top_scores = df3.sort_values(by='imdb_score', ascending=False)

# %%
top10_scores = top_scores.head(10)

# %%
top10_scores.plot(kind = 'barh', y = 'imdb_score',  ylabel = 'imdb_score', x = 'title', title = 'Most rated Movies', color = 'green')
# Out:
# <Axes: title={'center': 'Most rated Movies'}, ylabel='imdb_score'>
